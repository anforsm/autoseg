# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
import json
import glob
import wandb
import pandas as pd
import seaborn as sns
from autoseg.config import read_config
from autoseg.utils import get_artifact_base_path
from pathlib import Path

# %%
def get_vals_for_metric(metric, files):
  xs = []
  vals = []
  for f in sorted(files, key=lambda x: int(x.split("/")[-2].split("-")[1])):
    xs.append(int(f.split("/")[-2].split("-")[1]))
    results = json.load(open(f))
    vals.append(results["best_edits"][metric])
    #vals.append(results["best_nvi"][metric])
  return xs, vals

def get_metrics_for_model(config):
  config = read_config("autoseg/user_configs/anton/" + config)
  results = []
  for dataset in config["evaluation"]["datasets"]:
    path = Path(get_artifact_base_path(config)) / Path(config["evaluation"]["results_dir"])
    path = path.absolute().as_posix()
    files = glob.glob(path + "/step-*/" + dataset["output"])
    for f in files:
      if "step-0" in f:
        files.remove(f)
    print("files", files)

    xs = get_vals_for_metric("voi_sum", files)[0]
    _, merges = get_vals_for_metric("total_merges_needed_to_fix_splits", files)
    _, splits = get_vals_for_metric("total_splits_needed_to_fix_merges", files)
    skel_mods = np.array(merges) + np.array(splits)
    xs = np.array(xs)

    voi_sum = np.array(get_vals_for_metric("voi_sum", files)[1])
    nvi_sum = np.array(get_vals_for_metric("nvi_sum", files)[1])
    path_length = get_vals_for_metric("total path length", files)[1]
    results.append({
      "dataset": [dataset["name"] for _ in range(len(xs))],
      "checkpoints": xs,
      "merges": merges,
      "splits": splits,
      "skel_mods": skel_mods,
      "num_segments": get_vals_for_metric("number_of_segments", files)[1],
      "skel_splits": get_vals_for_metric("total_splits_needed_to_fix_merges", files)[1],
      "skel_merges": get_vals_for_metric("total_merges_needed_to_fix_splits", files)[1],
      "avg_skel_merges": get_vals_for_metric("average_merges_needed_to_fix_splits", files)[1],
      "avg_skel_splits": get_vals_for_metric("average_splits_needed_to_fix_merges", files)[1],
      "voi_sum": voi_sum,
      "voi_merge": get_vals_for_metric("voi_merge", files)[1],
      "voi_split": get_vals_for_metric("voi_split", files)[1],
      "nvi_sum": nvi_sum,
      "nvi_merge": get_vals_for_metric("nvi_merge", files)[1],
      "nvi_split": get_vals_for_metric("nvi_split", files)[1],
      "total_path_length": path_length,
      "threshold": get_vals_for_metric("threshold", files)[1],
    })
  return results

# %%
import pandas as pd
def create_dataframe(models, ds):
  metrics_example = get_metrics_for_model(models[list(models.keys())[0]][0])[0]
  df = pd.DataFrame(columns=["Model Type", "Run", "Run Name"] + list(metrics_example.keys()))
  for group_name, group in models.items():
    for model_i, model in enumerate(group):
      metrics = get_metrics_for_model(model)
      new_metrics = None
      for metric in metrics:
        print("====")
        print(metric["dataset"])
        print(type(metric["dataset"]))
        if isinstance(metric["dataset"], list) and len(metric["dataset"]) == 0:
          continue
        if metric["dataset"][0] in ds:
          if new_metrics is None:
            new_metrics = pd.DataFrame(metric)
          else:
            new_metrics = pd.concat([new_metrics, pd.DataFrame(metric)])
      metrics = new_metrics.to_dict("list")
      for i, checkpoint in enumerate(metrics["checkpoints"]):
        df.loc[len(df)] = [group_name, model_i, model] + [metrics[key][i] for key in metrics.keys()]
  return df

# %%
c = {
  "skel_mods": "Total Edits",
  "checkpoints": "Update Steps",
  "voi_sum": "VOI",
  "nvi_sum": "NVI",
  "normalized_skel_mods": "Normalized Total Edits"
}

# %%
baseline = create_dataframe({
  "Baseline Unet OSA": ["baselines/unet/1"]#, "baselines/unet/2", "baselines/unet/3"]
}, ["BBCHZ", "BLSNK", "BRNLG", "CLZBJ", "CRQCR", "CSKBZ", "DRZNC", "DTZVX", "GFBZX", "HNVRR", "HVCBQ", "JJPSC", "KSGRS", "MCZJJ", "MFBCF"])
#baseline["normalized_skel_mods"] = baseline["skel_mods"] / baseline["total_path_length"]
baseline.rename(columns=c, inplace=True)
# Out:
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BBCHZ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BLSNK_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BRNLG_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/CLZBJ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/CRQCR_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/CSKBZ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/DRZNC_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/DTZVX_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/GFBZX_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/HNVRR_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/HVCBQ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/JJPSC_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/KSGRS_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/MCZJJ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/MFBCF_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/MPLTJ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/NDKZB_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/QRFNB_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/RFHTC_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/RJZQR_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/RLCVK_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/SRQHN_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/TYLYL_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/YSJNL_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BBCHZ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BLSNK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BLSNK_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BRNLG_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BRNLG_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/CLZBJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/CLZBJ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/CRQCR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/CRQCR_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/CSKBZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/CSKBZ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/DRZNC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/DRZNC_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/DTZVX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/DTZVX_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/GFBZX_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/GFBZX_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/HNVRR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/HNVRR_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/HVCBQ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/HVCBQ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/JJPSC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/JJPSC_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/KSGRS_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/KSGRS_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/MCZJJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/MCZJJ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/MFBCF_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/MFBCF_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/MPLTJ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/MPLTJ_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/NDKZB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/NDKZB_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/QRFNB_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/QRFNB_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/RFHTC_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/RFHTC_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/RJZQR_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/RJZQR_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/RLCVK_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/RLCVK_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/SRQHN_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/SRQHN_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/TYLYL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/TYLYL_results.json']
# files ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/YSJNL_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/YSJNL_results.json']
# ====
# ['BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ']
# <class 'list'>
# ====
# ['BLSNK', 'BLSNK', 'BLSNK', 'BLSNK', 'BLSNK', 'BLSNK', 'BLSNK', 'BLSNK']
# <class 'list'>
# ====
# ['BRNLG', 'BRNLG', 'BRNLG', 'BRNLG', 'BRNLG', 'BRNLG', 'BRNLG', 'BRNLG']
# <class 'list'>
# ====
# ['CLZBJ', 'CLZBJ', 'CLZBJ', 'CLZBJ', 'CLZBJ', 'CLZBJ', 'CLZBJ', 'CLZBJ']
# <class 'list'>
# ====
# ['CRQCR', 'CRQCR', 'CRQCR', 'CRQCR', 'CRQCR', 'CRQCR', 'CRQCR', 'CRQCR']
# <class 'list'>
# ====
# ['CSKBZ', 'CSKBZ', 'CSKBZ', 'CSKBZ', 'CSKBZ', 'CSKBZ', 'CSKBZ', 'CSKBZ']
# <class 'list'>
# ====
# ['DRZNC', 'DRZNC', 'DRZNC', 'DRZNC', 'DRZNC', 'DRZNC', 'DRZNC', 'DRZNC']
# <class 'list'>
# ====
# ['DTZVX', 'DTZVX', 'DTZVX', 'DTZVX', 'DTZVX', 'DTZVX', 'DTZVX', 'DTZVX']
# <class 'list'>
# ====
# ['GFBZX', 'GFBZX', 'GFBZX', 'GFBZX', 'GFBZX', 'GFBZX', 'GFBZX', 'GFBZX']
# <class 'list'>
# ====
# ['HNVRR', 'HNVRR', 'HNVRR', 'HNVRR', 'HNVRR', 'HNVRR', 'HNVRR', 'HNVRR']
# <class 'list'>
# ====
# ['HVCBQ', 'HVCBQ', 'HVCBQ', 'HVCBQ', 'HVCBQ', 'HVCBQ', 'HVCBQ', 'HVCBQ']
# <class 'list'>
# ====
# ['JJPSC', 'JJPSC', 'JJPSC', 'JJPSC', 'JJPSC', 'JJPSC', 'JJPSC', 'JJPSC']
# <class 'list'>
# ====
# ['KSGRS', 'KSGRS', 'KSGRS', 'KSGRS', 'KSGRS', 'KSGRS', 'KSGRS', 'KSGRS']
# <class 'list'>
# ====
# ['MCZJJ', 'MCZJJ', 'MCZJJ', 'MCZJJ', 'MCZJJ', 'MCZJJ', 'MCZJJ', 'MCZJJ']
# <class 'list'>
# ====
# ['MFBCF', 'MFBCF', 'MFBCF', 'MFBCF', 'MFBCF', 'MFBCF', 'MFBCF', 'MFBCF']
# <class 'list'>
# ====
# ['MPLTJ', 'MPLTJ', 'MPLTJ', 'MPLTJ', 'MPLTJ', 'MPLTJ', 'MPLTJ', 'MPLTJ']
# <class 'list'>
# ====
# ['NDKZB', 'NDKZB', 'NDKZB', 'NDKZB', 'NDKZB', 'NDKZB', 'NDKZB', 'NDKZB']
# <class 'list'>
# ====
# ['QRFNB', 'QRFNB', 'QRFNB', 'QRFNB', 'QRFNB', 'QRFNB', 'QRFNB', 'QRFNB']
# <class 'list'>
# ====
# ['RFHTC', 'RFHTC', 'RFHTC', 'RFHTC', 'RFHTC', 'RFHTC', 'RFHTC', 'RFHTC']
# <class 'list'>
# ====
# ['RJZQR', 'RJZQR', 'RJZQR', 'RJZQR', 'RJZQR', 'RJZQR', 'RJZQR', 'RJZQR']
# <class 'list'>
# ====
# ['RLCVK', 'RLCVK', 'RLCVK', 'RLCVK', 'RLCVK', 'RLCVK', 'RLCVK', 'RLCVK']
# <class 'list'>
# ====
# ['SRQHN', 'SRQHN', 'SRQHN', 'SRQHN', 'SRQHN', 'SRQHN', 'SRQHN', 'SRQHN']
# <class 'list'>
# ====
# ['TYLYL', 'TYLYL', 'TYLYL', 'TYLYL', 'TYLYL', 'TYLYL', 'TYLYL', 'TYLYL']
# <class 'list'>
# ====
# ['YSJNL', 'YSJNL', 'YSJNL', 'YSJNL', 'YSJNL', 'YSJNL', 'YSJNL', 'YSJNL']
# <class 'list'>

# %%
sns.stripplot(data=baseline, x=c["checkpoints"], y=c["skel_mods"], hue="dataset", dodge=True, jitter=0, linewidth=0.4)
plt.show()

# %%
sns.stripplot(data=baseline, x=c["checkpoints"], y=c["skel_mods"], hue="dataset", dodge=True, jitter=0, linewidth=0.4)
plt.show()

# %%
def agg(group, by):
  return group.agg({
    c["skel_mods"]: by,
    c["voi_sum"]: by,
    c["nvi_sum"]: by
  })

# %%
mean = agg(baseline.groupby(["Model Type", c["checkpoints"]]), "mean").reset_index()

# %%
sns.stripplot(data=mean, x=c["checkpoints"], y="avg_skel_splits", hue="Model Type", dodge=True, jitter=0, linewidth=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 sns.stripplot(data=mean, x=c["checkpoints"], y="avg_skel_splits", hue="Model Type", dodge=True, jitter=0, linewidth=0.4)
#       2 plt.show()
#
# File ~/miniforge3/envs/segmentation/lib/python3.9/site-packages/seaborn/categorical.py:2089, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, style, **kwargs)
#    2081 def stripplot(
#    2082     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2083     jitter=True, dodge=False, orient=None, color=None, palette=None,
#    (...)
#    2086     ax=None, style=None, **kwargs
#    2087 ):
# -> 2089     p = _CategoricalPlotter(
#    2090         data=data,
#    2091         variables=dict(x=x, y=y, hue=hue, style=style),
#    2092         order=order,
#    2093         orient=orient,
#    2094         color=color,
#    2095         legend=legend,
#    2096     )
#    2098     if ax is None:
#    2099         ax = plt.gca()
#
# File ~/miniforge3/envs/segmentation/lib/python3.9/site-packages/seaborn/categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~/miniforge3/envs/segmentation/lib/python3.9/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/miniforge3/envs/segmentation/lib/python3.9/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/miniforge3/envs/segmentation/lib/python3.9/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/miniforge3/envs/segmentation/lib/python3.9/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `avg_skel_splits` for `y`. An entry with this name does not appear in `data`.

# %%
masked = create_dataframe({
  "Baseline Unet OSA": ["baselines/unet/1"]#, "baselines/unet/2", "baselines/unet/3"]
}, "BBCHZ")
masked["normalized_skel_mods"] = masked["skel_mods"] / masked["total_path_length"]
masked.rename(columns=c, inplace=True)
# Out:
# ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/oblique_results.json']
# ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BBCHZ_results.json']
# ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BBCHZ_no_mask_results.json']
# Empty DataFrame
# Columns: [Model Type, Run, Run Name, dataset, checkpoints, merges, splits, skel_mods, skel_splits, skel_merges, voi_sum, voi_merge, voi_split, nvi_sum, nvi_merge, nvi_split, total_path_length, threshold]
# Index: []
# ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/oblique_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/oblique_results.json']
# ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BBCHZ_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BBCHZ_results.json']
# ['/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-75000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-200000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-125000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-150000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-25000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-175000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-50000/BBCHZ_no_mask_results.json', '/home/anton/github/autoseg/src/autoseg/artifacts/UNet_OSA_run_1/results/step-100000/BBCHZ_no_mask_results.json']
# {'dataset': ['BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ', 'BBCHZ'], 'checkpoints': array([ 25000,  50000,  75000, 100000, 125000, 150000, 175000, 200000]), 'merges': [313, 365, 242, 145, 125, 277, 254, 141], 'splits': [82, 328, 125, 115, 96, 124, 74, 114], 'skel_mods': array([395, 693, 367, 260, 221, 401, 328, 255]), 'skel_splits': [82, 328, 125, 115, 96, 124, 74, 114], 'skel_merges': [313, 365, 242, 145, 125, 277, 254, 141], 'voi_sum': array([5.84673174, 5.82378157, 5.48197465, 5.75017126, 5.7131612 ,
#        5.49493101, 5.47175212, 5.66134459]), 'voi_merge': [2.923969497693685, 3.4459565287025953, 3.007400907890391, 3.027106747831528, 3.001149579245375, 2.9628063322155755, 3.0020356047785564, 3.004889826340304], 'voi_split': [2.922762244500939, 2.377825042622491, 2.4745737396617447, 2.723064510899599, 2.7120116255248714, 2.532124679118361, 2.4697165104117067, 2.656454768642334], 'nvi_sum': array([0.71831775, 0.76683785, 0.71275102, 0.72422295, 0.72056469,
#        0.70912943, 0.71187148, 0.71906793]), 'nvi_merge': [0.35923303673040424, 0.45374124599165094, 0.3910138609043433, 0.38125823913021023, 0.3785159119981031, 0.3823547861813794, 0.3905629288065751, 0.3816619635802799], 'nvi_split': [0.3590847160208775, 0.31309660716929955, 0.32173716164645894, 0.34296470754037917, 0.34204878053533183, 0.32677464596374783, 0.3213085521347447, 0.3374059622002962], 'total_path_length': [459090.8018500805, 459090.8018500805, 459090.8018500805, 459090.8018500805, 459090.8018500805, 459090.8018500805, 459090.8018500805, 459090.8018500805], 'threshold': [0.6, 0.6, 0.6, 0.8, 0.8, 0.6, 0.6, 0.8]}
